# %%
print("Hello Shit")
# Out:
# Hello Shit

# %%
def add(*args):
    return sum(args)

# %%
print(add(40.0, 70.0, 20.0, 30.0,495.6, 495.6, 495.6, 10.0, 50.0, 50.0, 60.0, 100.0, 70.0, 50.0, 400.0, 50.0, 70.0, 40.0, 40.0, 45.0, 60.0, 30.0, 15.0, 30.0, 49.1))
# Out:
# 2865.9
